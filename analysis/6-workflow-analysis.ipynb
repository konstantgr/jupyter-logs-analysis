# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

import numpy as np
import pandas as pd
import yaml
from matplotlib import pyplot as plt

from analysis.dataset.june_dataset import JuNEDataset
from analysis.metrics.metrics_cells import CellsMetrics


def read_config(config_path: Path = Path("data_config.yaml")) -> dict:
    with config_path.open("r") as stream:
        try:
            return yaml.safe_load(stream)
        except yaml.YAMLError:
            return {}


config = read_config()

# %%
df_hack = pd.read_csv(config.get("dataset_path"), index_col=0)
df_labels = pd.read_csv(config.get("label_mapping_path"), index_col=0)
df_hack = df_hack.merge(df_labels, on='action_id')

df_hack.head()
# Out:
#    action_id                     time                            session_id  \
# 0          0  2023-05-06 10:32:26.282  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 1          1  2023-05-06 10:32:55.892  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 2          2  2023-05-06 10:32:56.229  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 3          3  2023-05-06 10:32:58.048  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 4          4  2023-05-06 10:32:58.429  709ce80b-90a5-457e-bf6f-b7033a3261b5
#
#                               kernel_id notebook_name             event  \
# 0  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb     save_notebook
# 1  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb           execute
# 2  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  finished_execute
# 3  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb           execute
# 4  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  finished_execute
#
#                          cell_index  cell_num cell_type  \
# 0                               NaN       NaN       NaN
# 1  35c0b3b694f84140846a21197ea62f68       0.0      code
# 2  35c0b3b694f84140846a21197ea62f68       0.0      code
# 3  35c0b3b694f84140846a21197ea62f68       0.0      code
# 4  35c0b3b694f84140846a21197ea62f68       0.0      code
#
#                                          cell_source  \
# 0  [\n  {\n    "id": "35c0b3b694f84140846a21197ea...
# 1  from mining_extension import check_logging \nc...
# 2  from mining_extension import check_logging \nc...
# 3  from mining_extension import check_logging \nc...
# 4  from mining_extension import check_logging \nc...
#
#                             cell_output    user_id  expert        cell_label
# 0                                   NaN  student_7   False               NaN
# 1                                   NaN  student_7   False  helper_functions
# 2  [{"output_type":"stream","size":23}]  student_7   False  helper_functions
# 3                                   NaN  student_7   False  helper_functions
# 4  [{"output_type":"stream","size":23}]  student_7   False  helper_functions

# %%
june = JuNEDataset(df_hack)
june.prepare_dataset()
june.df.head()
# Out:
#    action_id                    time                            session_id  \
# 0          0 2023-05-06 10:32:26.282  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 1          1 2023-05-06 10:32:55.892  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 2          2 2023-05-06 10:32:56.229  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 3          3 2023-05-06 10:32:58.048  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 4          4 2023-05-06 10:32:58.429  709ce80b-90a5-457e-bf6f-b7033a3261b5
#
#                               kernel_id notebook_name             event  \
# 0  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb     save_notebook
# 1  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb           execute
# 2  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  finished_execute
# 3  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb           execute
# 4  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  finished_execute
#
#                          cell_index cell_num cell_type  \
# 0                              None     None      None
# 1  35c0b3b694f84140846a21197ea62f68      0.0      code
# 2  35c0b3b694f84140846a21197ea62f68      0.0      code
# 3  35c0b3b694f84140846a21197ea62f68      0.0      code
# 4  35c0b3b694f84140846a21197ea62f68      0.0      code
#
#                                          cell_source  \
# 0  [\n  {\n    "id": "35c0b3b694f84140846a21197ea...
# 1  from mining_extension import check_logging \nc...
# 2  from mining_extension import check_logging \nc...
# 3  from mining_extension import check_logging \nc...
# 4  from mining_extension import check_logging \nc...
#
#                             cell_output    user_id  expert        cell_label  \
# 0                                  None  student_7   False
# 1                                  None  student_7   False  helper_functions
# 2  [{"output_type":"stream","size":23}]  student_7   False  helper_functions
# 3                                  None  student_7   False  helper_functions
# 4  [{"output_type":"stream","size":23}]  student_7   False  helper_functions
#
#     task
# 0  task1
# 1  task1
# 2  task1
# 3  task1
# 4  task1

# %%
data_df = june.df
data_df['quartile'] = None
data_df
# Out:
#        action_id                    time  \
# 0              0 2023-05-06 10:32:26.282
# 1              1 2023-05-06 10:32:55.892
# 2              2 2023-05-06 10:32:56.229
# 3              3 2023-05-06 10:32:58.048
# 4              4 2023-05-06 10:32:58.429
# ...          ...                     ...
# 23617      23617 2023-08-18 18:00:52.629
# 23618      23618 2023-08-18 18:01:10.991
# 23619      23619 2023-08-18 18:01:14.946
# 23620      23620 2023-08-18 18:01:45.019
# 23621      23621 2023-08-18 18:02:46.545
#
#                                  session_id  \
# 0      709ce80b-90a5-457e-bf6f-b7033a3261b5
# 1      709ce80b-90a5-457e-bf6f-b7033a3261b5
# 2      709ce80b-90a5-457e-bf6f-b7033a3261b5
# 3      709ce80b-90a5-457e-bf6f-b7033a3261b5
# 4      709ce80b-90a5-457e-bf6f-b7033a3261b5
# ...                                     ...
# 23617  9889103b-e51e-418f-b890-ab42ef266bc5
# 23618  9889103b-e51e-418f-b890-ab42ef266bc5
# 23619  9889103b-e51e-418f-b890-ab42ef266bc5
# 23620  9889103b-e51e-418f-b890-ab42ef266bc5
# 23621  9889103b-e51e-418f-b890-ab42ef266bc5
#
#                                   kernel_id notebook_name             event  \
# 0      bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb     save_notebook
# 1      bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb           execute
# 2      bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  finished_execute
# 3      bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb           execute
# 4      bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  finished_execute
# ...                                     ...           ...               ...
# 23617  789ccc53-ffd3-48ba-9135-13fc8c1ce0c0   task1.ipynb  finished_execute
# 23618  789ccc53-ffd3-48ba-9135-13fc8c1ce0c0   task1.ipynb           execute
# 23619  789ccc53-ffd3-48ba-9135-13fc8c1ce0c0   task1.ipynb  finished_execute
# 23620  789ccc53-ffd3-48ba-9135-13fc8c1ce0c0   task1.ipynb           execute
# 23621  789ccc53-ffd3-48ba-9135-13fc8c1ce0c0   task1.ipynb  finished_execute
#
#                              cell_index cell_num cell_type  \
# 0                                  None     None      None
# 1      35c0b3b694f84140846a21197ea62f68      0.0      code
# 2      35c0b3b694f84140846a21197ea62f68      0.0      code
# 3      35c0b3b694f84140846a21197ea62f68      0.0      code
# 4      35c0b3b694f84140846a21197ea62f68      0.0      code
# ...                                 ...      ...       ...
# 23617  aa46744a5169409ab0eaef0df6319217     35.0      code
# 23618  351dbffd267149b18870f078fff8b438     33.0      code
# 23619  351dbffd267149b18870f078fff8b438     34.0      code
# 23620  aa46744a5169409ab0eaef0df6319217     34.0      code
# 23621  aa46744a5169409ab0eaef0df6319217     35.0      code
#
#                                              cell_source  \
# 0      [\n  {\n    "id": "35c0b3b694f84140846a21197ea...
# 1      from mining_extension import check_logging \nc...
# 2      from mining_extension import check_logging \nc...
# 3      from mining_extension import check_logging \nc...
# 4      from mining_extension import check_logging \nc...
# ...                                                  ...
# 23617  for i in range(len(list(array_of_dates))):\n  ...
# 23618  import copy\nall_datas = list(df['action_time'...
# 23619  import copy\nall_datas = list(df['action_time'...
# 23620  for i in range(len(list(array_of_dates))):\n  ...
# 23621  for i in range(len(list(array_of_dates))):\n  ...
#
#                                              cell_output     user_id  expert  \
# 0                                                   None   student_7   False
# 1                                                   None   student_7   False
# 2                   [{"output_type":"stream","size":23}]   student_7   False
# 3                                                   None   student_7   False
# 4                   [{"output_type":"stream","size":23}]   student_7   False
# ...                                                  ...         ...     ...
# 23617  [{"output_type":"stream","size":38978},{"outpu...  student_10   False
# 23618                                               None  student_10   False
# 23619              [{"output_type":"stream","size":704}]  student_10   False
# 23620                                               None  student_10   False
# 23621  [{"output_type":"stream","size":10487},{"outpu...  student_10   False
#
#              cell_label   task  index quartile
# 0                        task1      0     None
# 1      helper_functions  task1      1     None
# 2      helper_functions  task1      2     None
# 3      helper_functions  task1      3     None
# 4      helper_functions  task1      4     None
# ...                 ...    ...    ...      ...
# 23617  data_exploration  task1  23617     None
# 23618                    task1  23618     None
# 23619                    task1  23619     None
# 23620  data_exploration  task1  23620     None
# 23621  data_exploration  task1  23621     None
#
# [23622 rows x 17 columns]

# %%
lim = 10
res = dict(tuple(data_df.groupby(['user_id', 'notebook_name'])))
user_notebook_index = {
    k: v['index'].to_list() for k, v in res.items()
}

user_notebook_quartiles = {}
for k, v in res.items():
    quartiles = []
    if len(v) == 1:
        user_notebook_quartiles[k] = [0]
        continue

    limits = range(0, len(v), round(len(v) / lim))
    for i in range(lim):
        times = (
            abs(len(v) - (round(len(v) / lim) * i))
            if i == (lim - 1)
            else round(len(v) / lim)
        )
        tmp_list = [i] * times
        for each in tmp_list:
            quartiles.append(each)

    user_notebook_quartiles[k] = quartiles

# %%
for k, v in user_notebook_quartiles.items():
    i = user_notebook_index.get(k)
    if len(i) == len(v):
        for idx in range(len(i)):
            data_df.loc[i[idx], 'quartile'] = v[idx]
    else:
        print("error in ", k)

# %%
labels = [
    'helper_functions', 'load_data',
    'data_preprocessing', 'data_exploration',
    'modelling', 'evaluation', 'prediction',
    'result_visualization', 'save_results',
    'comment_only'
]

# %%
df_plot = pd.DataFrame(labels, columns=['labels'])
df_plot.set_index('labels', inplace=True)
quartiles = set(data_df.quartile.values)

for each in quartiles:
    df_plot[each] = None

for label in labels:
    temp = data_df[data_df['cell_label'] == label].quartile.value_counts().to_dict()
    for k, v in temp.items():
        df_plot.loc[label, k] = v

# %%
df_plot.dropna(axis=1, how='all', inplace=True)
df_plot.fillna(0, inplace=True)

# %%
import seaborn as sns

sns.reset_orig()
plt.style.use('https://github.com/klieret/simple-science-style/raw/main/stylesheets/sss1.mplstyle')
plt.rcParams["font.family"] = "Times New Roman"

fig, axs = plt.subplots(2, 3, figsize=(11, 5))
fig.subplots_adjust(left=7, bottom=7, right=9, top=9, wspace=0.2, hspace=0.5)
index = 0

labels_to_plot = [
    'helper_functions', 'data_exploration', 'data_exploration',
    'load_data', 'result_visualization', 'modelling'
]
# Plot each axis
for row in range(1, 3):
    for col in range(1, 4):
        y = list(df_plot.loc[labels_to_plot[index]][list(quartiles)].values)
        x = list(quartiles)
        tot = sum(y)
        values = [str(round((each / tot) * 100, 2)) + "%" for each in y]
        plot = sns.barplot(
            ax=axs[row - 1, col - 1], x=x, y=y, color='gray',
            linewidth=1.5, edgecolor="k"
        )

        plot.set_title(labels_to_plot[index], fontsize=20)
        axs[row - 1, col - 1].tick_params(axis='x', rotation=0)
        for p, val in zip(plot.patches, y):
            plot.annotate(" " + str(round((val / tot) * 100, 2)) + "%",
                          xy=(p.get_x() + p.get_width() / 2,
                              p.get_height()), ha='center',
                          va='bottom',
                          rotation=90, fontsize=12)
        index += 1
        axs[row - 1, col - 1].set_ylim(0, max(y) * 1.8)
        plot.minorticks_off()

fig.supxlabel("Time bin", fontsize=20)
fig.supylabel("No. of events", fontsize=20)

# custom_ylim = (0, 1500)
# plt.setp(axs, ylim=custom_ylim)
fig.tight_layout()
fig.savefig('figures/workflow/ds_steps_over_notebook_new.pdf', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# /Users/konstantingrotov/Library/Caches/pypoetry/virtualenvs/jupyter-logging-backend-FOYMgaQR-py3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
