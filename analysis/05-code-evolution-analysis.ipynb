# %%
# %load_ext autoreload
# %autoreload 2

import itertools
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import pingouin as pg
import seaborn as sns
import yaml
from matplotlib import pyplot as plt

from analysis.dataset.june_dataset import JuNEDataset
from analysis.metrics.metrics_cells import CellsMetrics

sns.reset_orig()
warnings.filterwarnings("ignore")

plt.style.use('https://github.com/klieret/simple-science-style/raw/main/stylesheets/sss1.mplstyle')
plt.rcParams["font.family"] = "Times New Roman"


def read_config(config_path: Path = Path("data_config.yaml")) -> dict:
    with config_path.open("r") as stream:
        try:
            return yaml.safe_load(stream)
        except yaml.YAMLError:
            return {}


config = read_config()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Read data

# %%
df_hack = pd.read_csv(config.get("dataset_path"), index_col=0)
df_labels = pd.read_csv(config.get("label_mapping_path"), index_col=0)
df_hack = df_hack.merge(df_labels, on='action_id')

df_hack.head()
# Out:
#    action_id                     time                            session_id  \
# 0          0  2023-05-06 10:32:26.282  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 1          1  2023-05-06 10:32:55.892  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 2          2  2023-05-06 10:32:56.229  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 3          3  2023-05-06 10:32:58.048  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 4          4  2023-05-06 10:32:58.429  709ce80b-90a5-457e-bf6f-b7033a3261b5
#
#                               kernel_id notebook_name             event  \
# 0  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb     save_notebook
# 1  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb           execute
# 2  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  finished_execute
# 3  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb           execute
# 4  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  finished_execute
#
#                          cell_index  cell_num cell_type  \
# 0                               NaN       NaN       NaN
# 1  35c0b3b694f84140846a21197ea62f68       0.0      code
# 2  35c0b3b694f84140846a21197ea62f68       0.0      code
# 3  35c0b3b694f84140846a21197ea62f68       0.0      code
# 4  35c0b3b694f84140846a21197ea62f68       0.0      code
#
#                                          cell_source  \
# 0  [\n  {\n    "id": "35c0b3b694f84140846a21197ea...
# 1  from mining_extension import check_logging \nc...
# 2  from mining_extension import check_logging \nc...
# 3  from mining_extension import check_logging \nc...
# 4  from mining_extension import check_logging \nc...
#
#                             cell_output    user_id  expert        cell_label
# 0                                   NaN  student_7   False               NaN
# 1                                   NaN  student_7   False  helper_functions
# 2  [{"output_type":"stream","size":23}]  student_7   False  helper_functions
# 3                                   NaN  student_7   False  helper_functions
# 4  [{"output_type":"stream","size":23}]  student_7   False  helper_functions

# %%
june = JuNEDataset(df_hack)
june.prepare_dataset()
june.df.head()
# Out:
#    action_id                    time                            session_id  \
# 0          0 2023-05-06 10:32:26.282  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 1          1 2023-05-06 10:32:55.892  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 2          2 2023-05-06 10:32:56.229  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 3          3 2023-05-06 10:32:58.048  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 4          4 2023-05-06 10:32:58.429  709ce80b-90a5-457e-bf6f-b7033a3261b5
#
#                               kernel_id notebook_name             event  \
# 0  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb     save_notebook
# 1  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb           execute
# 2  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  finished_execute
# 3  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb           execute
# 4  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  finished_execute
#
#                          cell_index cell_num cell_type  \
# 0                              None     None      None
# 1  35c0b3b694f84140846a21197ea62f68      0.0      code
# 2  35c0b3b694f84140846a21197ea62f68      0.0      code
# 3  35c0b3b694f84140846a21197ea62f68      0.0      code
# 4  35c0b3b694f84140846a21197ea62f68      0.0      code
#
#                                          cell_source  \
# 0  [\n  {\n    "id": "35c0b3b694f84140846a21197ea...
# 1  from mining_extension import check_logging \nc...
# 2  from mining_extension import check_logging \nc...
# 3  from mining_extension import check_logging \nc...
# 4  from mining_extension import check_logging \nc...
#
#                             cell_output    user_id  expert        cell_label  \
# 0                                  None  student_7   False
# 1                                  None  student_7   False  helper_functions
# 2  [{"output_type":"stream","size":23}]  student_7   False  helper_functions
# 3                                  None  student_7   False  helper_functions
# 4  [{"output_type":"stream","size":23}]  student_7   False  helper_functions
#
#     task
# 0  task1
# 1  task1
# 2  task1
# 3  task1
# 4  task1

# %%
evolution_df = june.to_evolution_dataframe()
evolution_df
# Out:
# 100%|██████████| 31/31 [00:25<00:00,  1.22it/s]
#     state_num                        cell_index  cell_num  \
# 0           1  35c0b3b694f84140846a21197ea62f68       0.0
# 0           2  35c0b3b694f84140846a21197ea62f68       0.0
# 0           3  35c0b3b694f84140846a21197ea62f68       0.0
# 0           4  35c0b3b694f84140846a21197ea62f68       0.0
# 0           5  35c0b3b694f84140846a21197ea62f68       0.0
# ..        ...                               ...       ...
# 14        497  dd4006fccad344ae8e13f2a49946b42e      14.0
# 15        497  f372fcf1d6b9403587d8f226e65df63b      15.0
# 16        497  795bf5ffdb9a4bdfa5f0ed2937ea16dd      16.0
# 17        497  b5843c42fca14f1a86a780e0caaf704c      17.0
# 18        497  5f7f4e7a57634a058a9e3cec2462c1e5      18.0
#
#                                           cell_source  action_id  \
# 0   # # Do not forget to check if your notebook lo...        0.0
# 0   from mining_extension import check_logging \nc...        1.0
# 0   from mining_extension import check_logging \nc...        2.0
# 0   from mining_extension import check_logging \nc...        3.0
# 0   from mining_extension import check_logging \nc...        4.0
# ..                                                ...        ...
# 14  re.findall(r'[(]\S*', split2[0])[0].replace('(...    23053.0
# 15  re.findall(r'\S*[d+:]\S*', split2[0])[0].repla...    23053.0
# 16  \n\nfor i in df.iloc[:1,0]:\n    split1 = i.sp...    23053.0
# 17  df_final = pd.DataFrame()\n\n\nfor i in df.ilo...    23053.0
# 18                                           df_final    23053.0
#
#                       time                            session_id  \
# 0  2023-05-06 10:32:26.282  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 0  2023-05-06 10:32:55.892  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 0  2023-05-06 10:32:56.229  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 0  2023-05-06 10:32:58.048  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 0  2023-05-06 10:32:58.429  709ce80b-90a5-457e-bf6f-b7033a3261b5
# ..                     ...                                   ...
# 14 2023-08-18 14:49:30.859  275683a9-81a4-47d8-89f0-f4f3564106bb
# 15 2023-08-18 14:49:30.859  275683a9-81a4-47d8-89f0-f4f3564106bb
# 16 2023-08-18 14:49:30.859  275683a9-81a4-47d8-89f0-f4f3564106bb
# 17 2023-08-18 14:49:30.859  275683a9-81a4-47d8-89f0-f4f3564106bb
# 18 2023-08-18 14:49:30.859  275683a9-81a4-47d8-89f0-f4f3564106bb
#
#                                kernel_id notebook_name             event  \
# 0   bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb     save_notebook
# 0   bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb           execute
# 0   bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  finished_execute
# 0   bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb           execute
# 0   bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  finished_execute
# ..                                   ...           ...               ...
# 14  b12216b9-46d7-486c-9fa9-21d843da13dc   task1.ipynb  finished_execute
# 15  b12216b9-46d7-486c-9fa9-21d843da13dc   task1.ipynb  finished_execute
# 16  b12216b9-46d7-486c-9fa9-21d843da13dc   task1.ipynb  finished_execute
# 17  b12216b9-46d7-486c-9fa9-21d843da13dc   task1.ipynb  finished_execute
# 18  b12216b9-46d7-486c-9fa9-21d843da13dc   task1.ipynb  finished_execute
#
#    cell_type                                     cell_output    user_id  \
# 0       None                                            None  student_7
# 0       code                                            None  student_7
# 0       code            [{"output_type":"stream","size":23}]  student_7
# 0       code                                            None  student_7
# 0       code            [{"output_type":"stream","size":23}]  student_7
# ..       ...                                             ...        ...
# 14      code  [{"output_type":"execute_result","size":2661}]   expert_7
# 15      code  [{"output_type":"execute_result","size":2661}]   expert_7
# 16      code  [{"output_type":"execute_result","size":2661}]   expert_7
# 17      code  [{"output_type":"execute_result","size":2661}]   expert_7
# 18      code  [{"output_type":"execute_result","size":2661}]   expert_7
#
#    expert        cell_label   task
# 0   False                    task1
# 0   False  helper_functions  task1
# 0   False  helper_functions  task1
# 0   False  helper_functions  task1
# 0   False  helper_functions  task1
# ..    ...               ...    ...
# 14   True      comment_only  task1
# 15   True      comment_only  task1
# 16   True      comment_only  task1
# 17   True      comment_only  task1
# 18   True      comment_only  task1
#
# [557623 rows x 16 columns]

# %%
evolution_df.shape
# Out:
# (557623, 16)

# %%
mask = (
    evolution_df.event.isin(["execute", "create", "delete", "rendered"])
)
evolution_df[mask].head()
# Out:
#    state_num                        cell_index  cell_num  \
# 0          2  35c0b3b694f84140846a21197ea62f68       0.0
# 0          4  35c0b3b694f84140846a21197ea62f68       0.0
# 0          6  35c0b3b694f84140846a21197ea62f68       0.0
# 0          7  35c0b3b694f84140846a21197ea62f68       0.0
# 0          9  35c0b3b694f84140846a21197ea62f68       0.0
#
#                                          cell_source  action_id  \
# 0  from mining_extension import check_logging \nc...        1.0
# 0  from mining_extension import check_logging \nc...        3.0
# 0  from mining_extension import check_logging \nc...        5.0
# 0  from mining_extension import check_logging \nc...        6.0
# 0  from mining_extension import check_logging \nc...        8.0
#
#                      time                            session_id  \
# 0 2023-05-06 10:32:55.892  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 0 2023-05-06 10:32:58.048  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 0 2023-05-06 10:33:01.263  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 0 2023-05-06 10:33:06.253  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 0 2023-05-06 10:33:09.812  709ce80b-90a5-457e-bf6f-b7033a3261b5
#
#                               kernel_id notebook_name    event cell_type  \
# 0  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  execute      code
# 0  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  execute      code
# 0  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  execute      code
# 0  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  execute      code
# 0  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  execute      code
#
#   cell_output    user_id expert        cell_label   task
# 0        None  student_7  False  helper_functions  task1
# 0        None  student_7  False  helper_functions  task1
# 0        None  student_7  False  helper_functions  task1
# 0        None  student_7  False  helper_functions  task1
# 0        None  student_7  False  helper_functions  task1

# %% [markdown]
# # Metrics calculation

# %%
processor = CellsMetrics()

df_tmp = evolution_df[mask]
df_tmp['event'] = 'execute'

df_analysis = processor.calculate_cell_metrics(df_tmp)
df_analysis.head()
# Out:
# 303995it [01:02, 4854.33it/s]
#    state_num                        cell_index  cell_num  \
# 0          2  35c0b3b694f84140846a21197ea62f68       0.0
# 1          4  35c0b3b694f84140846a21197ea62f68       0.0
# 2          6  35c0b3b694f84140846a21197ea62f68       0.0
# 3          7  35c0b3b694f84140846a21197ea62f68       0.0
# 4          9  35c0b3b694f84140846a21197ea62f68       0.0
#
#                                          cell_source  action_id  \
# 0  from mining_extension import check_logging \nc...        1.0
# 1  from mining_extension import check_logging \nc...        3.0
# 2  from mining_extension import check_logging \nc...        5.0
# 3  from mining_extension import check_logging \nc...        6.0
# 4  from mining_extension import check_logging \nc...        8.0
#
#                      time                            session_id  \
# 0 2023-05-06 10:32:55.892  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 1 2023-05-06 10:32:58.048  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 2 2023-05-06 10:33:01.263  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 3 2023-05-06 10:33:06.253  709ce80b-90a5-457e-bf6f-b7033a3261b5
# 4 2023-05-06 10:33:09.812  709ce80b-90a5-457e-bf6f-b7033a3261b5
#
#                               kernel_id notebook_name    event cell_type  \
# 0  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  execute      code
# 1  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  execute      code
# 2  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  execute      code
# 3  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  execute      code
# 4  bc147b33-fa74-4bff-9f48-c88809c5bdcd   task1.ipynb  execute      code
#
#   cell_output    user_id expert        cell_label   task  objects  sloc  ccn  \
# 0        None  student_7  False  helper_functions  task1        1     2    1
# 1        None  student_7  False  helper_functions  task1        1     2    1
# 2        None  student_7  False  helper_functions  task1        1     2    1
# 3        None  student_7  False  helper_functions  task1        1     2    1
# 4        None  student_7  False  helper_functions  task1        1     2    1
#
#    comments
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# # Analysis

# %%
def continuous_transform(
        x, y, size: int = 1000, normalize: bool = True
) -> tuple[np.ndarray, np.ndarray]:
    x_max = 1 if normalize else np.max(x)
    xp = np.linspace(0, x_max, size)
    x = np.linspace(0, x_max, len(y))
    y = np.array(y)

    y[np.isnan(y)] = 0
    y = np.interp(xp, x, y) + 1e-5
    return xp, y

# %%
_, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 3))
metric_name = 'objects'
aggregation_function = 'mean'
task_ax_mapping = {'task1': ax1, 'task2': ax2}
mean_curve = {'task1': [], 'task2': []}

df = df_analysis
df = df[df.comments <= df.comments.quantile(0.95)]

size_threshold = 200
mn, mx = np.inf, -np.inf
leg = True
for (task, kernel_id), g in df.groupby(['task', 'kernel_id']):
    if g.shape[0] < size_threshold:
        continue
    events_count = g.state_num.unique().shape[0]
    if metric_name == "cells_num":
        agg_fun_values = g.groupby("state_num").cell_index.agg('count')
    else:
        agg_fun_values = g.groupby("state_num")[metric_name].agg(aggregation_function)

    x, y = continuous_transform(
        np.arange(events_count), agg_fun_values,
        normalize=True
    )
    mean_curve[task].append(y)

    mn = y.min() if y.min() < mn else mn
    mx = y.max() if y.max() > mx else mx
    task_ax_mapping[task].plot(x, y, color='k', alpha=0.2)

for task, curves in mean_curve.items():
    y = np.sum(curves, axis=0) / len(curves)
    x = np.linspace(0, 1, len(y))

    task_ax_mapping[task].axhline(y[-1], color='k', ls=(0, (5, 5)))
    task_ax_mapping[task].plot(x, y, color='firebrick', lw=3, label="Average")

for task, ax in task_ax_mapping.items():
    ax.set_ylim(mn * 0.9, mx * 1.1)
    ax.set_xlim(0, 1)
    ax.set_xlabel('Normalized Time', fontsize=14)
    ax.set_ylabel(f"{metric_name.capitalize()} ({aggregation_function})", fontsize=14)
    ax.set_title("DA task" if task == "task1" else "ML task", fontsize=14)
    ax.grid(False)

for line in task_ax_mapping['task2'].lines[-3:-2]:
    line.set_label(s='Individual notebook')

ax2.set_ylabel(None)
ax2.set_yticklabels([])
plt.tight_layout()
plt.legend()
plt.savefig(
    f"figures/evolution/{metric_name}_{aggregation_function}_tasks.pdf",
    dpi=300, bbox_inches='tight'
)
plt.show()

# %%
df_tmp = df.groupby(['kernel_id', 'state_num'])[['sloc', 'ccn', 'objects']] \
    .agg(['mean', 'sum']).reset_index()

df_tmp = df_tmp.loc[df_tmp.groupby('kernel_id').state_num.idxmax()].set_index("kernel_id")
df_tmp['task'] = df_analysis[['task', 'kernel_id']] \
    .drop_duplicates(keep='last').set_index('kernel_id')['task']

df_tmp['expert'] = june.df[['expert', 'kernel_id']] \
    .drop_duplicates(keep='last').set_index('kernel_id')['expert']

df_tmp = df_tmp.reset_index()

cols = list(itertools.product(['sloc', 'ccn', 'objects'], ['mean', 'sum'], ['mean']))
table = df_tmp.drop('state_num', axis=1).groupby(["task", "expert"]).describe().loc[:, cols]
table.round(2)
# Out:
#               sloc          ccn        objects
#               mean    sum  mean    sum    mean    sum
#               mean   mean  mean   mean    mean   mean
# task  expert
# task1 False   2.24  77.57  0.97  41.57    1.88  74.00
#       True    2.32  53.40  0.99  21.60    2.40  54.60
# task2 False   4.27  87.67  0.95  19.33    4.35  83.67
#       True    2.45  78.50  0.85  27.67    3.25  98.67

# %%
print(table.round(2).applymap('{:.2f}'.format).to_latex(escape=True, multirow=True))
# Out:
# \begin{tabular}{llllllll}
# \toprule
#  &  & \multicolumn{2}{r}{sloc} & \multicolumn{2}{r}{ccn} & \multicolumn{2}{r}{objects} \\
#  &  & mean & sum & mean & sum & mean & sum \\
#  &  & mean & mean & mean & mean & mean & mean \\
# task & expert &  &  &  &  &  &  \\
# \midrule
# \multirow[t]{2}{*}{task1} & False & 2.24 & 77.57 & 0.97 & 41.57 & 1.88 & 74.00 \\
#  & True & 2.32 & 53.40 & 0.99 & 21.60 & 2.40 & 54.60 \\
# \cline{1-8}
# \multirow[t]{2}{*}{task2} & False & 4.27 & 87.67 & 0.95 & 19.33 & 4.35 & 83.67 \\
#  & True & 2.45 & 78.50 & 0.85 & 27.67 & 3.25 & 98.67 \\
# \cline{1-8}
# \bottomrule
# \end{tabular}

# %%
cols = list(itertools.product(['sloc', 'ccn', 'objects'], ['mean', 'sum']))

table = df_tmp.drop('state_num', axis=1).describe().loc["mean", cols]
table.round(2)
# Out:
# sloc     mean     2.69
#          sum     75.81
# ccn      mean     0.95
#          sum     31.35
# objects  mean     2.71
#          sum     77.52
# Name: mean, dtype: float64

# %%
df_tmp = df_analysis.groupby(['kernel_id', 'state_num'])[['sloc', 'ccn', 'objects']] \
    .agg(['mean', 'sum']).reset_index()
df_tmp.columns = ['_'.join(col).strip("_") for col in df_tmp.columns.values]

df_tmp = pd.merge(
    df_tmp,
    df_analysis[['task', 'kernel_id']] \
        .drop_duplicates(keep='last')[['kernel_id', 'task']],
    on='kernel_id'
)

df_tmp = pd.merge(
    df_tmp,
    june.df[['expert', 'kernel_id']] \
        .drop_duplicates(keep='last')[['kernel_id', 'expert']],
    on='kernel_id'
)

max_values = df_tmp.groupby('kernel_id')['state_num'].transform('max')
df_tmp['normalized_state'] = df_tmp['state_num'] / max_values

metrics_list = list(df_tmp)[2:-3]

df_corr = df_tmp.groupby(['task', 'expert'])[['normalized_state', *metrics_list]].corr(method="spearman")
indices = [i for i in df_corr.index if i[-1] == 'normalized_state']
df_corr[metrics_list] = df_corr[metrics_list]

table = df_corr.loc[indices][metrics_list]
table.round(3)
# Out:
#                                sloc_mean  sloc_sum  ccn_mean  ccn_sum  \
# task  expert
# task1 False  normalized_state     -0.071     0.533    -0.062    0.636
#       True   normalized_state      0.171     0.688    -0.077    0.655
# task2 False  normalized_state      0.432     0.577     0.171    0.487
#       True   normalized_state      0.134     0.585    -0.029    0.510
#
#                                objects_mean  objects_sum
# task  expert
# task1 False  normalized_state        -0.007        0.562
#       True   normalized_state         0.195        0.698
# task2 False  normalized_state         0.572        0.614
#       True   normalized_state         0.528        0.698

# %%
table.columns = pd.MultiIndex.from_tuples([tuple(i.split('_')) for i in table.columns.to_list()])
table = table.reset_index().drop(columns='level_2')

# %%
pretty_lang = {
    'task1': 'DS', 'task2': 'ML', np.NaN: 'All',
    False: 'Student', True: 'Professional'
}

new_names = [
    'Task', 'Level of expertise', 'SLOC',
    'SLOC', 'CCN', 'CCN', 'N of objects', 'N of objects'
]

table.columns = pd.MultiIndex.from_tuples(
    [(new_names[i], column[1]) for i, column in enumerate(table.columns.to_list())]
)

table = table.replace(pretty_lang).set_index(['Task', 'Level of expertise']).applymap(
    lambda x: str.format("{:0_.2f}", x)
)
table
# Out:
#                           SLOC          CCN       N of objects
#                           mean   sum   mean   sum         mean   sum
# Task Level of expertise
# DS   Student             -0.07  0.53  -0.06  0.64        -0.01  0.56
#      Professional         0.17  0.69  -0.08  0.65         0.20  0.70
# ML   Student              0.43  0.58   0.17  0.49         0.57  0.61
#      Professional         0.13  0.59  -0.03  0.51         0.53  0.70

# %%
print(table.to_latex(escape=True, multirow=True))
# Out:
# \begin{tabular}{llllllll}
# \toprule
#  &  & \multicolumn{2}{r}{SLOC} & \multicolumn{2}{r}{CCN} & \multicolumn{2}{r}{N of objects} \\
#  &  & mean & sum & mean & sum & mean & sum \\
# Task & Level of expertise &  &  &  &  &  &  \\
# \midrule
# \multirow[t]{2}{*}{DS} & Student & -0.07 & 0.53 & -0.06 & 0.64 & -0.01 & 0.56 \\
#  & Professional & 0.17 & 0.69 & -0.08 & 0.65 & 0.20 & 0.70 \\
# \cline{1-8}
# \multirow[t]{2}{*}{ML} & Student & 0.43 & 0.58 & 0.17 & 0.49 & 0.57 & 0.61 \\
#  & Professional & 0.13 & 0.59 & -0.03 & 0.51 & 0.53 & 0.70 \\
# \cline{1-8}
# \bottomrule
# \end{tabular}

# %%
alpha = 0.05
pairs = (itertools.product(['task1', 'task2'], [True, False]))

for (task, expert) in pairs:
    for metric in metrics_list:
        df_sample = df_tmp[
            (df_tmp.task == task) & (df_tmp.expert == expert)
            ][['normalized_state', metric]]

        cor = pg.corr(df_sample.normalized_state, df_sample[metric], method="spearman")
        if cor['p-val'].iloc[0] > alpha:
            print(metric, task, expert, cor['r'].iloc[0].round(2), cor['p-val'].iloc[0].round(2))
# Out:
# objects_mean task1 False -0.01 0.58
# ccn_mean task2 True -0.03 0.11
